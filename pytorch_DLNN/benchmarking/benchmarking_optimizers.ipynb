# %%
import seaborn
import torch
import torchvision

# %%
train_dataset = torchvision.datasets.MNIST(root="/home/xd/Documents/py_codes/ML_Notebooks/dataset", download=True, train=True)
test_dataset = torchvision.datasets.MNIST(root="/home/xd/Documents/py_codes/ML_Notebooks/dataset", download=True, train=False)

print(train_dataset.data.shape, train_dataset.targets.shape, test_dataset.data.shape, test_dataset.targets.shape, type(train_dataset.data), type(train_dataset.targets))
# Out:
# torch.Size([60000, 28, 28]) torch.Size([60000]) torch.Size([10000, 28, 28]) torch.Size([10000]) <class 'torch.Tensor'> <class 'torch.Tensor'>
